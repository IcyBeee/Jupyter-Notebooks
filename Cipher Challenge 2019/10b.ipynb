# %% [markdown]
# # Bonus Challenge 10b

# %%
message = "..."

# %%
from collections import Counter

# Takes a string or list of items and counts the frequencies of those items
# data: The list or string to analyse
# max_values: The maximum number of values to display (set to None for no limit)
# no_columns: The amount of columns to use in the output
def frequency_analysis(data, max_values=30, no_columns=5):
    frequencies = Counter()
    for item in data:
        frequencies[item] += 1
    
    total = sum(frequencies.values())
    column = 1
    for item, frequency in frequencies.most_common(max_values):
        print(f"{item}: {frequency:2} ({frequency / total:.2%})", end=" " if column % no_columns else "\n")
        column += 1
    print("\n-----")
    
frequency_analysis(message)
# Out:
# D: 718 (16.13%) A: 688 (15.45%) G: 652 (14.65%) J: 467 (10.49%) H: 461 (10.35%)
# B: 425 (9.55%) E: 395 (8.87%) L: 349 (7.84%) K: 297 (6.67%)
# -----

# %%
# OK - 9 different letters: AB DE GH JKL
# I guess the missing letters are significant.  Perhaps the encoding is similar to 9b, but with the fourth digit in ternary.
# There are two messages encoded in here, so I'm guessing each letter represents a combination of two digits.
# So let's go for...
letter_map = {'A':(0, 0), 'B':(0, 1), 'D':(0, 2), 'E':(1, 0), 'G':(1, 1), 'H':(1, 2), 'J':(2, 0), 'K':(2, 1), 'L':(2, 2)}

sequence1 = []
sequence2 = []
for letter in message:
    n1, n2 = letter_map[letter]
    sequence1.append(n1)
    sequence2.append(n2)

# %%
for i in range(len(sequence1)//4):
    print(sequence1[i*4:(i*4)+4])
# Out:
# [2, 0, 0, 1]
# [1, 0, 2, 0]
# [1, 2, 1, 0]
# [2, 1, 1, 0]
# [2, 0, 1, 0]
# [0, 2, 1, 0]
# [1, 2, 0, 0]
# [0, 2, 1, 0]
# [0, 0, 2, 1]
# [2, 0, 0, 1]
# [0, 0, 1, 2]
# [0, 2, 1, 1]
# [0, 2, 0, 1]
# [0, 1, 2, 0]
# [0, 2, 1, 1]
# [0, 2, 1, 0]
# [2, 0, 1, 0]
# [0, 2, 1, 1]
# [0, 2, 0, 1]
# [0, 2, 1, 0]
# [1, 2, 0, 0]
# [1, 0, 1, 2]
# [2, 0, 0, 1]
# [1, 2, 0, 0]
# [0, 2, 1, 0]
# [1, 2, 1, 0]
# [1, 2, 1, 0]
# [1, 0, 1, 2]
# [0, 1, 2, 0]
# [1, 0, 2, 0]
# [2, 1, 1, 0]
# [0, 1, 2, 0]
# [2, 0, 1, 1]
# [1, 0, 2, 0]
# [1, 0, 1, 2]
# [0, 2, 1, 1]
# [1, 0, 1, 2]
# [1, 2, 1, 0]
# [1, 0, 0, 2]
# [1, 2, 0, 0]
# [0, 0, 2, 1]
# [2, 0, 1, 1]
# [0, 2, 0, 1]
# [0, 2, 0, 1]
# [2, 0, 0, 1]
# [1, 0, 2, 0]
# [1, 2, 1, 0]
# [0, 0, 2, 1]
# [2, 0, 1, 1]
# [1, 0, 2, 0]
# [0, 2, 1, 0]
# [1, 2, 0, 0]
# [0, 0, 2, 1]
# [0, 2, 1, 1]
# [0, 2, 1, 0]
# [0, 1, 2, 0]
# [0, 1, 0, 2]
# [0, 0, 1, 2]
# [0, 2, 0, 1]
# [1, 2, 0, 1]
# [0, 0, 1, 2]
# [0, 0, 1, 2]
# [0, 1, 2, 1]
# [0, 1, 2, 0]
# [1, 2, 1, 0]
# [0, 1, 0, 2]
# ...
