# %% [markdown]
# # Cipher Challenge 2021
# ### Mission 10
#
# Challenge link https://www.cipherchallenge.org/challenge/mission-10/

# %%
# Part A - "On the rocks"
part_a_text = """NTDNJ PWHTH DTONE ORRAO TSMES COETI ELETN UIDHY RHNHN IMWYI CCOYR RENHS NRWGL SOHNK GDRHR LMAMI MKTTA HICEN TRDEW EWBWD EAOHN USRBL TTNIL NEDEI TLNSV MTEGY ATILS WAUSA EEWTT LEOER LETSU TIAEL HEOIW QWECO JENRN HFWNA WDNER SAHTF XTIPL ITHCI OHATA NIWOO NIRBA RLLGA ODFTY DVENM HEMOE DHTOE LHSAT HOTUA TAOST TNFHS OSGET ARSLH CEHTD THSYI OEIIU LDETA THFGV UKTBU JSETT EVNTF LMDLE TTMES TATED TAAOL LCJHA ESIEI SCIOY OREES EFEER AASON ANHAS ENORN HAABN THLAB LMTAT IOEYE HIEFY EIAAT ILSIE IHCPH SHNDE AWRAN ETTHL ENFAI ENOAP ITVNP IDPTE UHCYD ODTBT EAHTM HODPO IVOTI PTRTC SBAHN DARHN EOOHW DSELR SOOHN LALHT IEDWA EYMVM IITMB CAIRA FRHDG OYNPH ODOOU RIHSU BMTVI HLEFW OATAT OEIAE TOENE NISHA EHEUE DHYNC EAHSL NSOOT ETSEW ITALK TLTDA TEOOL IFGOA OLNKO WICAO DWAEE WERAT EIWTR ATOOI NRONE ATEOD OTEBI SDORA IFAIH ESEAA RDAAT HNEWR HRRTD CEMKR OEOID TTPIM EDSAH HKACH HTSGS HATSN EEESR DAIEL IVESE WAEEA PULRN TARJD PEKIT ETDUH EICEA FIEOA NNTEO WETTH OLHNT HCSLW AERGT OLBSD SNNEU DSIFR UISVO DOTIB TSNSI RRDTR ERMAE THDHE OAESW EBTOA AUEIE THOFA MIUER ECTRR ELTYN SLLEO OARDF TRDPH TNTNS RSOHO DNISC BVINO ELLNT MMEEC TYSWO ISYEI HDLLN CMTEO ATTSN TNWVB TTSRE OOAGA GHESA INAPU HEEBT IDNOT RITDI ETASB IWREA OTODI FULWC ESNAW HLNOE PHLLH AOLTE TAIIV TIDXN NUNEG IEOCV RTDEG UEHNR BHCTH OEATS HMUAT TLNOE EIENA FIIRE RRNIS CINLY OENOI MOIPV OGROD DDTIE ENTWA RSHDN NDETU ENDDN ODATE TEOIO LUIOS OQWIE UYAIE EYEMH LHAES NMEWA DTSHA DDFNN BSDHO HTSAT AENME EUKEM WYRHL PEYOI YOUAT NEAAE HRYOD SMLMU REANE EUCRS HDSIT IECRI DDOOD TEWIB FWTIT LEIAP IYJHN HKLFH ASWNI EMTRG OINOA DRLEA IAOES DICAA HEOUR MNLAC GRENC CLIAH UNNIA MCEOT CSSAS MNHUI BEAEA CCACE IUOHT LLNII SBEEL ONTNH DERNA EEHMR OSEWD ETSAO IIEON AAEAS NNNNE DPMOL MNBMY EFHLB RNDIT LHOWA TRVAA EHOMN SDAEO EOIID YIWTT FARUN TOSCH CREHO HTTLP BBHUR POMDE CHTHW SLMNU ECIPE HEAHD BOFUT ETTSD VAODO EDFAI MDTTE ETTGL HTWSY HEIUI OLISO TIERC OAONB WICYN ALIGL YCBFG LEHHT HSOCO IELNN AHANO YHHTB IIDWF IERMN ITHAI ETRSG HFDRA SMEVT STTNA EAREI ASVTN LNUDT EJHTN NYGHA MSDSS PSSHB MLTSO NHETY EIUES NDFRD YHFTA RIRSN DGHPT IRRNC YNLOR LDHAR ONSEH HSRTE NRKTY PDRCT PITRE HTNRR CFIRN DAEOE DHENG SLALL MERHD ATIHE ETOEI EMYYO CNMNF IESEP UMNAH TLONI CMANI NTRGA IVHVD UNWDR LFAHA LOHLL HSEIE AEHTD LNMRE AWERO TWDNH DENLB HIOEV EOMLS TCATA SGAUI EWLOU MTCBT AIOOL NEAEL EOROE FNVNE ONAAT LERIH FAEPN LIEGI RRDRE ADYSD GBNMH RREUI IIKNR ETEEI FRAHO SCDDA RDDIT RYEEI IWEHT HEAFA RYJVT HEETD WYLEW EPICC YATEO LSPAC NIAYT WRAOF NNEIT STDAE YAMEA TMWDR NTANL YODGI NIYAY FNJTF SEDOI SNHGA UNITS TNRWI TOTOI ENTOT HEACN FIEEA ECAEI LARTE EONIP TTNTR RNWLH EEIMT IESEW SYOHH ANOTS BEOTN TWYTR CRNWE NORSE TETUT TESBE FBDKO EARLU EOELM WIOOB ISEIA RETEE DTESO TLDUT CUMWA JHRIN OANTT OUUOP ATANN TMSFT AOECS ADAFE CROTU RITTE GYTOE OABAN ELDSA NIRTS EEDIE SAEEW TBWNC HANTL BIESD ATEEE TTRTY WVTKO EETEL IDACM NIACR AWWIL RIHAA HABOS INHOA DAESA ENUII HDPEN TOLWN RWHCV TENUE OAVTT VEFFP EEEAC EAYYT EIILD EIEGN SASMU OATET CPOEI NAARD CYAIT NMAPR UMIDE NULTI EWOID A"""

# %%
from collections import Counter

# Takes a string or list of items and counts the frequencies of those items
# data: The list or string to analyse
# max_values: The maximum number of values to display (set to None for no limit)
# no_columns: The amount of columns to use in the output
def frequency_analysis(data, max_values=30, no_columns=5):
    frequencies = Counter()
    for item in data:
        frequencies[item] += 1
    
    total = sum(frequencies.values())
    column = 1
    for item, frequency in frequencies.most_common(max_values):
        print(f"{item}: {frequency:2} ({frequency / total:.2%})", end=" " if column % no_columns else "\n")
        column += 1
    print("\n-----")

# %%
squished = part_a_text.replace(" ", "")
frequency_analysis(squished)
# Out:
# E: 314 (12.50%) T: 247 (9.84%) A: 215 (8.56%) I: 189 (7.53%) N: 183 (7.29%)
# O: 178 (7.09%) H: 154 (6.13%) R: 133 (5.30%) S: 130 (5.18%) D: 125 (4.98%)
# L: 110 (4.38%) W: 70 (2.79%) C: 70 (2.79%) M: 66 (2.63%) U: 59 (2.35%)
# Y: 54 (2.15%) F: 47 (1.87%) B: 43 (1.71%) P: 36 (1.43%) G: 32 (1.27%)
# V: 28 (1.12%) K: 14 (0.56%) J: 10 (0.40%) Q:  2 (0.08%) X:  2 (0.08%)
#
# -----

# %%
# Looks like a transposition cipher
message_length = len(squished)
for n in range(2, message_length//2):
    if message_length % n == 0:
        print(n, end=" ")
# Out:
# 3 9 27 31 81 93 279 837

# %%
# Most likely 9 columns...
no_columns = 9
column_height = message_length // no_columns
for row in range(column_height):
    for column in range(no_columns):
        print(squished[(column_height*column)+row], end="")
    print()
# Out:
# NIADGDTIE
# TOTTREEHL
# DEORORJFM
# NIEEDNHAW
# JIIRDATEI
# PUAMDENPO
# WLEATENNO
# HDTEIHYLB
# TEOTEMGII
# HTEHERHES
# DANDNOAGE
# TTEHTSMII
# OHNEWESRA
# NFIOAWDRR
# EGSARDSDE
# OVHESESRT
# RUASHTPEE
# RKEWDSSAE
# ATHENASDD
# OBEBNOHYT
# TUUTDIBSE
# SJEOEIMDS
# MSDATELGO
# EEHAUOTBT
# STYUENSNL
# CTNENAOMD
# OECIDANHU
# EVEEDEHRT
# TNATNAERC
# ITHHOSTEU
# EFSODNYUM
# LLLFANEIW
# EMNATNIIA
# TDSMENUIJ
# NLOITEEKH
# UEOUEDSNR
# ITTEOPNRI
# DTERIMDEN
# HMTEOOFTO
# YESCLLREA
# RSETUMDEN
# HTWRINYIT
# NAIROBHFT
# HTTESMFRO
# NEALOYTAU
# IDLTQEAHU
# MTKYWFROO
# WATNIHISP
# YALSELRCA
# IOTLUBSDT
# CLDLYRNDA
# CLAEANDAN
# OCTOIDGRN
# YJEOEIHDT
# RHOAETPDM
# RAORYLTIS
# EELDEHITF
# NSIFMORRT
# HIFTHWRYA
# SEGRLANEO
# NIODHTCEE
# RSAPARYIC
# WCOHEVNIS
# GILTSALWA
# LONNNAOED
# SYKTMERHA
# OOONEHLTF
# HRWSWODHE
# NEIRAMHEC
# KECSDNAAR
# GSAOTSRFO
# DEOHSDOAT
# RFDOHANRU
# HEWDAESYR
# REANDOEJI
# LREIDEHVT
# MAESFOHTT
# AAWCNISHE
# MSEBNIREG
# IORVBDTEY
# MNAISYETT
# KATNDINDO
# TNEOHWRWE
# ...

# %%
# Looks like a message from Harry...
# Last line  YTROHDROA
#            8 6 4 7 5            
no_columns = 9
column_height = message_length // no_columns
untangled = ""
for row in range(column_height):
    for column in (1, 3, 5, 7, 4, 8, 2, 6, 0):
        untangled += squished[(column_height*column)+row]
print(untangled)
# Out:
# ...

# %%
# Not quite - but nearly...
# IDDIGEATN - I did get an
# OTEHRLTET - other lett
# ERRFOMOJD - er from jod
# IENADWEHN - ie and when

no_columns = 9
column_height = message_length // no_columns
untangled = ""
for row in range(column_height):
    for column in (1, 3, 7, 5, 4, 8, 6, 2, 0):
        untangled += squished[(column_height*column)+row]
print(untangled)
# Out:
# ...

# %% [markdown]
# #### Edited for clarity
#
# I did get another letter from Jodie and when I read it, I jumped on a plane to New Delhi. By the time I got there, she had gone and this time, there was no forwarding address.<br/>
# Everest's house the park was deserted and shabby on the outside, but Jodie's message told me about the tunnel system and once I had uncovered the entrance at the south, I found myself in a well maintained mine, just like the one under Souter Point.<br/>
# It reminded me too of the cellar system under Trinity Wharf, both in terms of the layout and the quality of workmanship. It was clearly old but still dry and clean and, according to Jodie, they had temporarily stored the files from Trinity Wharf here alongside the conspiracy archives.<br/>
# Now it was all gone, and only the marks on the floor showed where machines and racks of storage had stood for a hundred years.  When Jodie arrived, the last of the machines was being removed by Trinity's team and I don't know where they took it. All that was left by then was a printer and a computer terminal connected to the conspiracy's main data centre by their own secure network. The whole establishment was powered by a hydro-electric dam in the foothills. It had apparently been built by Edison, who was recruited by Mary Boole to power the foundation machine and the fifteen analytic engines that she installed at the base and while it was relatively small by modern standards, it must have seemed a miracle at the time.<br/>
# The computing power they had here was greater than anything the world had ever seen, but it was locked away from curious eyes and they managed to keep it secret until now.<br/>
# This time, they did not leave a file by accident for me to find. Instead, Jodie printed a pile of documents for me to read and said it was up to me what I did with it.<br/>
# I still haven't broken the final page, which is attached, but I am hoping that it will answer the big questions...<br/>
# What was the conspiracy trying to do?<br/>
# Why has Jodie joined it?<br/>
# I haven't foundher, but I haven't looked. She will surface if and when she wants to and I am not sure what I will do when I find her.<br/>
# I have placed her on compassionate leave for now, hoping that the Boole file will explain what the conspiracy are up to and will clear her.<br/>
# I still can't believe that Agatha, Charlie, Trinity and Jodie could have been part of something dark and I live in expectation that we won't have to hunt her down.<br/>
# The founders of this group were incredible women: Caroline Herschel, Ada Lovelace, Florence Nightingale and Mary Boole. They had a giant influence on the society they lived in, while overshadowed by the men who built machines. The thing they had in common was a love of mathematics and it seems this brought them to a common cause, but I still can't see what that was. It was clearly important enough for them to recruit others, including Babbage, Wheatstone, Faraday and Edison. For a conspiracy on this scale to remain undetected for even a short time is unusual. For it to persist through centuries is almost unbelievable and for my friends to be involved is unthinkable.<br/>
# I choose to believe in them - at least for now and will not stop until I have understood.<br/>
# Harry

# %%
# Part B - "A state of enlightenment"
part_b_text = """..."""

# %%
squished = part_b_text.replace(" ", "")
frequency_analysis(squished, 36)
# Out:
# P: 428 (9.16%) V: 357 (7.64%) A: 326 (6.97%) Y: 287 (6.14%) O: 249 (5.33%)
# R: 233 (4.99%) H: 232 (4.96%) B: 197 (4.21%) W: 188 (4.02%) N: 177 (3.79%)
# D: 166 (3.55%) E: 162 (3.47%) C: 157 (3.36%) U: 156 (3.34%) 5: 153 (3.27%)
# F: 146 (3.12%) 8: 140 (3.00%) 6: 122 (2.61%) 2: 93 (1.99%) Z: 84 (1.80%)
# I: 74 (1.58%) T: 70 (1.50%) M: 70 (1.50%) 0: 60 (1.28%) 9: 59 (1.26%)
# 4: 48 (1.03%) J: 46 (0.98%) Q: 45 (0.96%) K: 38 (0.81%) 3: 26 (0.56%)
# L: 25 (0.53%) X: 19 (0.41%) S: 17 (0.36%) 7: 14 (0.30%) G:  9 (0.19%)
# 1:  1 (0.02%)
# -----

# %%
# 36 different characters.  Letters A-Z, plus 0-9.
# Only a single "1".

# A function that searches for multiple ocurrences of letters of the specified size and prints out the most common ones
def pattern_finder(text, size):
    patterns = Counter()
    for index in range(len(text)):
        patterns[text[index:index+size]] += 1

    column = 0
    for item, count in patterns.most_common(30):
        print(f"{item}: {count:2}", end=" ")
        column += 1
        if column % 5 == 0:
            print()
            
for n in range (10):
    pattern_finder(squished, n)
# Out:
# : 4674 P: 428 V: 357 A: 326 Y: 287 O: 249
# R: 233 H: 232 B: 197 W: 188 N: 177
# D: 166 E: 162 C: 157 U: 156 5: 153
# F: 146 8: 140 6: 122 2: 93 Z: 84
# I: 74 T: 70 M: 70 0: 60 9: 59
# 4: 48 J: 46 Q: 45 K: 38 3: 26
# HP: 75 VP: 62 DR: 54 VO: 51 YP: 50
# 6A: 44 EY: 43 AW: 43 YV: 41 OV: 41
# PW: 40 FV: 35 AV: 35 PU: 35 56: 34
# PV: 33 YB: 33 NP: 31 PO: 30 RA: 29
# 89: 28 BY: 28 VF: 27 VA: 27 RB: 27
# 8O: 26 WV: 25 UP: 25 ZV: 25 P0: 25
# HPP: 15 6AW: 15 HPO: 15 WVP: 15 VDR: 12
# PVF: 12 POV: 11 RYP: 11 DRB: 11 RPV: 11
# HP5: 10 PVO: 10 DHP: 10 P0E: 10 UAO: 10
# PWY:  9 YBA:  9 VP0:  9 N56:  9 6VO:  9
# 8YV:  9 UVP:  9 DQD:  8 56V:  8 BAR:  8
# 0EB:  8 EBV:  8 BVD:  8 HPF:  8 ZVP:  8
# HPOV:  9 RPVF:  9 YBAR:  8 0EBV:  8 EBVD:  8
# BVDR:  8 VP0E:  8 48UA:  8 56VO:  7 WLHP:  6
# RDQD:  6 PWY8:  6 NFAW:  6 HPPW:  6 YAQO:  6
# VPVO:  6 PUVP:  6 UAON:  6 89HP:  5 HP5C:  5
# RFYV:  5 EYAW:  5 QDHP:  5 AWOV:  5 BWVP:  5
# P0EB:  5 YDHP:  5 PYVP:  5 RBVA:  5 HWVP:  5
# ...

# %%
# Apparently it's something to do with bigrams.
# Look at the frequencies of odds and evens

frequency_analysis(squished[0::2], 36)
frequency_analysis(squished[1::2], 36)
# Out:
# V: 185 (7.92%) A: 181 (7.74%) H: 170 (7.27%) Y: 144 (6.16%) P: 140 (5.99%)
# O: 138 (5.91%) R: 124 (5.31%) B: 108 (4.62%) E: 93 (3.98%) 5: 90 (3.85%)
# N: 85 (3.64%) C: 81 (3.47%) U: 76 (3.25%) W: 73 (3.12%) D: 69 (2.95%)
# F: 68 (2.91%) 8: 62 (2.65%) 6: 53 (2.27%) I: 51 (2.18%) 2: 43 (1.84%)
# T: 35 (1.50%) Q: 35 (1.50%) 4: 34 (1.45%) 0: 34 (1.45%) Z: 33 (1.41%)
# M: 27 (1.16%) 9: 24 (1.03%) J: 21 (0.90%) K: 14 (0.60%) L: 11 (0.47%)
# S: 10 (0.43%) 7:  8 (0.34%) G:  6 (0.26%) 3:  5 (0.21%) X:  5 (0.21%)
# 1:  1 (0.04%)
# -----
# P: 288 (12.32%) V: 172 (7.36%) A: 145 (6.20%) Y: 143 (6.12%) W: 115 (4.92%)
# O: 111 (4.75%) R: 109 (4.66%) D: 97 (4.15%) N: 92 (3.94%) B: 89 (3.81%)
# U: 80 (3.42%) 8: 78 (3.34%) F: 78 (3.34%) C: 76 (3.25%) 6: 69 (2.95%)
# E: 69 (2.95%) 5: 63 (2.70%) H: 62 (2.65%) Z: 51 (2.18%) 2: 50 (2.14%)
# M: 43 (1.84%) 9: 35 (1.50%) T: 35 (1.50%) 0: 26 (1.11%) J: 25 (1.07%)
# K: 24 (1.03%) I: 23 (0.98%) 3: 21 (0.90%) L: 14 (0.60%) X: 14 (0.60%)
# ...
